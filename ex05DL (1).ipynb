# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras import layers
from keras.models import Sequential

# %%
dataset_train = pd.read_csv('trainset.csv')

# %%
dataset_train.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
dataset_train.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  02-01-2013  357.385559  361.151062  355.959839  359.288177  359.288177
# 1  03-01-2013  360.122742  363.600128  358.031342  359.496826  359.496826
# 2  04-01-2013  362.313507  368.339294  361.488861  366.600616  366.600616
# 3  07-01-2013  365.348755  367.301056  362.929504  365.001007  365.001007
# 4  08-01-2013  365.393463  365.771027  359.874359  364.280701  364.280701
#
#     Volume
# 0  5115500
# 1  4666500
# 2  5562800
# 3  3332900
# 4  3373900

# %%
train_set = dataset_train.iloc[:,1:2].values

# %%
type(train_set)
# Out:
# numpy.ndarray

# %%
train_set.shape
# Out:
# (1259, 1)

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(train_set)

# %%
training_set_scaled.shape
# Out:
# (1259, 1)

# %%
X_train_array = []
y_train_array = []
for i in range(60, 1259):
  X_train_array.append(training_set_scaled[i-60:i,0])
  y_train_array.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train_array), np.array(y_train_array)
X_train1 = X_train.reshape((X_train.shape[0], X_train.shape[1],1))

# %%
X_train.shape
# Out:
# (1199, 60)

# %%
length = 60
n_features = 1

# %%
model = Sequential()
model.add(layers.SimpleRNN(10,input_shape=(60,1)))
model.add(layers.Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10)                120
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 131 (524.00 Byte)
# Trainable params: 131 (524.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train1,y_train,epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 9ms/step - loss: 0.9393
# Epoch 2/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.1247
# Epoch 3/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0293
# Epoch 4/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0154
# Epoch 5/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0105
# Epoch 6/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0079
# Epoch 7/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0062
# Epoch 8/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0050
# Epoch 9/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0040
# Epoch 10/100
# 38/38 [==============================] - 1s 15ms/step - loss: 0.0032
# Epoch 11/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0027
# Epoch 12/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0023
# Epoch 13/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0020
# Epoch 14/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0019
# Epoch 15/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 16/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0016
# Epoch 17/100
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0015
# Epoch 18/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0014
# Epoch 19/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 20/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 21/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 22/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 23/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0011
# Epoch 24/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 25/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0010
# Epoch 26/100
# 38/38 [==============================] - 0s 10ms/step - loss: 9.5572e-04
# Epoch 27/100
# 38/38 [==============================] - 1s 23ms/step - loss: 9.1377e-04
# Epoch 28/100
# 38/38 [==============================] - 0s 10ms/step - loss: 8.7538e-04
# Epoch 29/100
# 38/38 [==============================] - 1s 27ms/step - loss: 8.7082e-04
# Epoch 30/100
# 38/38 [==============================] - 0s 10ms/step - loss: 8.2777e-04
# Epoch 31/100
# 38/38 [==============================] - 1s 20ms/step - loss: 7.9435e-04
# Epoch 32/100
# 38/38 [==============================] - 0s 12ms/step - loss: 7.5878e-04
# Epoch 33/100
# 38/38 [==============================] - 0s 9ms/step - loss: 7.6270e-04
# Epoch 34/100
# 38/38 [==============================] - 0s 12ms/step - loss: 7.2973e-04
# Epoch 35/100
# 38/38 [==============================] - 1s 15ms/step - loss: 7.0642e-04
# Epoch 36/100
# 38/38 [==============================] - 1s 17ms/step - loss: 6.9691e-04
# Epoch 37/100
# 38/38 [==============================] - 1s 16ms/step - loss: 6.5475e-04
# Epoch 38/100
# 38/38 [==============================] - 1s 16ms/step - loss: 6.4408e-04
# Epoch 39/100
# 38/38 [==============================] - 0s 11ms/step - loss: 6.2474e-04
# Epoch 40/100
# 38/38 [==============================] - 0s 11ms/step - loss: 6.0589e-04
# Epoch 41/100
# 38/38 [==============================] - 0s 10ms/step - loss: 5.9005e-04
# Epoch 42/100
# 38/38 [==============================] - 0s 10ms/step - loss: 5.9507e-04
# Epoch 43/100
# 38/38 [==============================] - 0s 10ms/step - loss: 5.5453e-04
# Epoch 44/100
# 38/38 [==============================] - 0s 10ms/step - loss: 5.5047e-04
# Epoch 45/100
# 38/38 [==============================] - 0s 11ms/step - loss: 5.4284e-04
# Epoch 46/100
# 38/38 [==============================] - 0s 10ms/step - loss: 5.2684e-04
# Epoch 47/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.9989e-04
# Epoch 48/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.9064e-04
# Epoch 49/100
# 38/38 [==============================] - 0s 10ms/step - loss: 4.7981e-04
# Epoch 50/100
# 38/38 [==============================] - 0s 10ms/step - loss: 4.8429e-04
# Epoch 51/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.8039e-04
# Epoch 52/100
# 38/38 [==============================] - 1s 16ms/step - loss: 4.7777e-04
# Epoch 53/100
# 38/38 [==============================] - 1s 16ms/step - loss: 4.4863e-04
# Epoch 54/100
# 38/38 [==============================] - 1s 16ms/step - loss: 4.3315e-04
# Epoch 55/100
# 38/38 [==============================] - 1s 15ms/step - loss: 4.2443e-04
# Epoch 56/100
# 38/38 [==============================] - 1s 15ms/step - loss: 4.1155e-04
# Epoch 57/100
# 38/38 [==============================] - 0s 12ms/step - loss: 4.1231e-04
# Epoch 58/100
# 38/38 [==============================] - 0s 11ms/step - loss: 4.1352e-04
# Epoch 59/100
# 38/38 [==============================] - 0s 10ms/step - loss: 3.9498e-04
# Epoch 60/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.9495e-04
# Epoch 61/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.9080e-04
# Epoch 62/100
# 38/38 [==============================] - 1s 15ms/step - loss: 3.7069e-04
# Epoch 63/100
# 38/38 [==============================] - 1s 16ms/step - loss: 3.7667e-04
# Epoch 64/100
# 38/38 [==============================] - 1s 15ms/step - loss: 3.7976e-04
# Epoch 65/100
# 38/38 [==============================] - 1s 15ms/step - loss: 3.5459e-04
# Epoch 66/100
# 38/38 [==============================] - 1s 17ms/step - loss: 3.6357e-04
# Epoch 67/100
# 38/38 [==============================] - 0s 10ms/step - loss: 3.4748e-04
# Epoch 68/100
# 38/38 [==============================] - 0s 10ms/step - loss: 3.4825e-04
# Epoch 69/100
# 38/38 [==============================] - 0s 10ms/step - loss: 3.3310e-04
# Epoch 70/100
# 38/38 [==============================] - 0s 10ms/step - loss: 3.3191e-04
# Epoch 71/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.1908e-04
# Epoch 72/100
# 38/38 [==============================] - 0s 10ms/step - loss: 3.2268e-04
# Epoch 73/100
# 38/38 [==============================] - 1s 13ms/step - loss: 3.1832e-04
# Epoch 74/100
# 38/38 [==============================] - 0s 13ms/step - loss: 3.1309e-04
# Epoch 75/100
# 38/38 [==============================] - 0s 11ms/step - loss: 3.3305e-04
# Epoch 76/100
# 38/38 [==============================] - 0s 10ms/step - loss: 3.1123e-04
# Epoch 77/100
# 38/38 [==============================] - 1s 13ms/step - loss: 3.0404e-04
# Epoch 78/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.9544e-04
# Epoch 79/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.8922e-04
# Epoch 80/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.8736e-04
# Epoch 81/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.8735e-04
# Epoch 82/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.7848e-04
# Epoch 83/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.8525e-04
# Epoch 84/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.7189e-04
# Epoch 85/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.9241e-04
# Epoch 86/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.8232e-04
# Epoch 87/100
# 38/38 [==============================] - 0s 8ms/step - loss: 2.7128e-04
# Epoch 88/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.7586e-04
# Epoch 89/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.8568e-04
# Epoch 90/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.7038e-04
# Epoch 91/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.7524e-04
# Epoch 92/100
# 38/38 [==============================] - 1s 13ms/step - loss: 2.8570e-04
# Epoch 93/100
# 38/38 [==============================] - 1s 14ms/step - loss: 2.7638e-04
# Epoch 94/100
# 38/38 [==============================] - 1s 18ms/step - loss: 2.8601e-04
# Epoch 95/100
# 38/38 [==============================] - 1s 16ms/step - loss: 3.1084e-04
# Epoch 96/100
# 38/38 [==============================] - 1s 16ms/step - loss: 2.6967e-04
# Epoch 97/100
# 38/38 [==============================] - 0s 12ms/step - loss: 2.5530e-04
# Epoch 98/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.4786e-04
# Epoch 99/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.5684e-04
# Epoch 100/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.5120e-04

# %%
dataset_test = pd.read_csv('testset.csv')

# %%
test_set = dataset_test.iloc[:,1:2].values

# %%
test_set.shape
# Out:
# (125, 1)

# %%
dataset_total = pd.concat((dataset_train['Open'],dataset_test['Open']),axis=0)

# %%
inputs = dataset_total.values
inputs = inputs.reshape(-1,1)
inputs_scaled=sc.transform(inputs)
X_test = []
y_test = []
for i in range(60,1384):
  X_test.append(inputs_scaled[i-60:i,0])
  y_test.append(inputs_scaled[i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
X_test.shape
# Out:
# (1324, 60, 1)

# %%
predicted_stock_price_scaled = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price_scaled)
# Out:
# 42/42 [==============================] - 0s 4ms/step

# %%
plt.plot(np.arange(0,1384),inputs, color='red', label = 'Test(Real) Google stock price')
plt.plot(np.arange(60,1384),predicted_stock_price, color='blue', label = 'Predicted Google stock price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error as mse
mse(y_test,predicted_stock_price)
# Out:
# 540767.9407047854
