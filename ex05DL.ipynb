# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras import layers
from keras.models import Sequential

# %%
dataset_train = pd.read_csv('trainset.csv')

# %%
dataset_train.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
dataset_train.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  02-01-2013  357.385559  361.151062  355.959839  359.288177  359.288177
# 1  03-01-2013  360.122742  363.600128  358.031342  359.496826  359.496826
# 2  04-01-2013  362.313507  368.339294  361.488861  366.600616  366.600616
# 3  07-01-2013  365.348755  367.301056  362.929504  365.001007  365.001007
# 4  08-01-2013  365.393463  365.771027  359.874359  364.280701  364.280701
#
#     Volume
# 0  5115500
# 1  4666500
# 2  5562800
# 3  3332900
# 4  3373900

# %%
train_set = dataset_train.iloc[:,1:2].values

# %%
type(train_set)
# Out:
# numpy.ndarray

# %%
train_set.shape
# Out:
# (1259, 1)

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(train_set)

# %%
training_set_scaled.shape
# Out:
# (1259, 1)

# %%
X_train_array = []
y_train_array = []
for i in range(60, 1259):
  X_train_array.append(training_set_scaled[i-60:i,0])
  y_train_array.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train_array), np.array(y_train_array)
X_train1 = X_train.reshape((X_train.shape[0], X_train.shape[1],1))

# %%
X_train.shape
# Out:
# (1199, 60)

# %%
length = 60
n_features = 1

# %%
model = Sequential()
model.add(layers.SimpleRNN(10,input_shape=(60,1)))
model.add(layers.Dense(1))

model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn (SimpleRNN)      (None, 10)                120
#
#  dense (Dense)               (None, 1)                 11
#
# =================================================================
# Total params: 131 (524.00 Byte)
# Trainable params: 131 (524.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train1,y_train,epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 9ms/step - loss: 0.1754
# Epoch 2/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0124
# Epoch 3/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0037
# Epoch 4/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0021
# Epoch 5/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0017
# Epoch 6/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0015
# Epoch 7/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0014
# Epoch 8/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0013
# Epoch 9/100
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0012
# Epoch 10/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0012
# Epoch 11/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 12/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 13/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0011
# Epoch 14/100
# 38/38 [==============================] - 0s 10ms/step - loss: 9.9153e-04
# Epoch 15/100
# 38/38 [==============================] - 0s 9ms/step - loss: 9.6482e-04
# Epoch 16/100
# 38/38 [==============================] - 0s 9ms/step - loss: 9.4586e-04
# Epoch 17/100
# 38/38 [==============================] - 0s 9ms/step - loss: 9.1295e-04
# Epoch 18/100
# 38/38 [==============================] - 0s 8ms/step - loss: 8.8338e-04
# Epoch 19/100
# 38/38 [==============================] - 0s 8ms/step - loss: 8.6480e-04
# Epoch 20/100
# 38/38 [==============================] - 0s 9ms/step - loss: 8.3806e-04
# Epoch 21/100
# 38/38 [==============================] - 0s 13ms/step - loss: 8.1046e-04
# Epoch 22/100
# 38/38 [==============================] - 1s 15ms/step - loss: 8.0199e-04
# Epoch 23/100
# 38/38 [==============================] - 1s 15ms/step - loss: 7.8034e-04
# Epoch 24/100
# 38/38 [==============================] - 1s 15ms/step - loss: 7.6195e-04
# Epoch 25/100
# 38/38 [==============================] - 1s 15ms/step - loss: 7.8442e-04
# Epoch 26/100
# 38/38 [==============================] - 1s 15ms/step - loss: 7.3841e-04
# Epoch 27/100
# 38/38 [==============================] - 0s 9ms/step - loss: 7.0687e-04
# Epoch 28/100
# 38/38 [==============================] - 0s 9ms/step - loss: 6.9757e-04
# Epoch 29/100
# 38/38 [==============================] - 0s 9ms/step - loss: 6.9347e-04
# Epoch 30/100
# 38/38 [==============================] - 0s 9ms/step - loss: 6.7175e-04
# Epoch 31/100
# 38/38 [==============================] - 0s 8ms/step - loss: 6.5578e-04
# Epoch 32/100
# 38/38 [==============================] - 0s 9ms/step - loss: 6.3143e-04
# Epoch 33/100
# 38/38 [==============================] - 0s 9ms/step - loss: 6.7266e-04
# Epoch 34/100
# 38/38 [==============================] - 0s 8ms/step - loss: 6.2041e-04
# Epoch 35/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.9876e-04
# Epoch 36/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.8786e-04
# Epoch 37/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.8966e-04
# Epoch 38/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.8497e-04
# Epoch 39/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.8465e-04
# Epoch 40/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.9638e-04
# Epoch 41/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.5108e-04
# Epoch 42/100
# 38/38 [==============================] - 0s 8ms/step - loss: 5.5742e-04
# Epoch 43/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.1852e-04
# Epoch 44/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.2882e-04
# Epoch 45/100
# 38/38 [==============================] - 0s 9ms/step - loss: 5.1829e-04
# Epoch 46/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.9333e-04
# Epoch 47/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.9508e-04
# Epoch 48/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.9325e-04
# Epoch 49/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.7043e-04
# Epoch 50/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.5293e-04
# Epoch 51/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.6940e-04
# Epoch 52/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.6816e-04
# Epoch 53/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.3763e-04
# Epoch 54/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.5179e-04
# Epoch 55/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.2636e-04
# Epoch 56/100
# 38/38 [==============================] - 1s 13ms/step - loss: 4.4329e-04
# Epoch 57/100
# 38/38 [==============================] - 1s 15ms/step - loss: 4.3561e-04
# Epoch 58/100
# 38/38 [==============================] - 1s 14ms/step - loss: 4.3337e-04
# Epoch 59/100
# 38/38 [==============================] - 1s 15ms/step - loss: 4.5213e-04
# Epoch 60/100
# 38/38 [==============================] - 1s 15ms/step - loss: 4.1941e-04
# Epoch 61/100
# 38/38 [==============================] - 1s 14ms/step - loss: 3.9069e-04
# Epoch 62/100
# 38/38 [==============================] - 0s 9ms/step - loss: 4.2836e-04
# Epoch 63/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.9657e-04
# Epoch 64/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.7957e-04
# Epoch 65/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.7412e-04
# Epoch 66/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.9267e-04
# Epoch 67/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.6488e-04
# Epoch 68/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.5369e-04
# Epoch 69/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.5180e-04
# Epoch 70/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.5185e-04
# Epoch 71/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.8410e-04
# Epoch 72/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.6209e-04
# Epoch 73/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.3489e-04
# Epoch 74/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.4752e-04
# Epoch 75/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.2975e-04
# Epoch 76/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.4494e-04
# Epoch 77/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.3650e-04
# Epoch 78/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.1677e-04
# Epoch 79/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.1792e-04
# Epoch 80/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.0320e-04
# Epoch 81/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.2172e-04
# Epoch 82/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.4748e-04
# Epoch 83/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.0764e-04
# Epoch 84/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.0280e-04
# Epoch 85/100
# 38/38 [==============================] - 0s 9ms/step - loss: 3.1015e-04
# Epoch 86/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.9391e-04
# Epoch 87/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.9191e-04
# Epoch 88/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.9572e-04
# Epoch 89/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.9448e-04
# Epoch 90/100
# 38/38 [==============================] - 0s 8ms/step - loss: 3.0266e-04
# Epoch 91/100
# 38/38 [==============================] - 1s 16ms/step - loss: 3.2185e-04
# Epoch 92/100
# 38/38 [==============================] - 1s 15ms/step - loss: 3.5850e-04
# Epoch 93/100
# 38/38 [==============================] - 1s 15ms/step - loss: 3.0284e-04
# Epoch 94/100
# 38/38 [==============================] - 1s 15ms/step - loss: 3.1706e-04
# Epoch 95/100
# 38/38 [==============================] - 1s 16ms/step - loss: 2.9406e-04
# Epoch 96/100
# 38/38 [==============================] - 0s 10ms/step - loss: 2.6906e-04
# Epoch 97/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.7980e-04
# Epoch 98/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.7093e-04
# Epoch 99/100
# 38/38 [==============================] - 0s 8ms/step - loss: 2.6163e-04
# Epoch 100/100
# 38/38 [==============================] - 0s 9ms/step - loss: 2.6295e-04

# %%
dataset_test = pd.read_csv('testset.csv')

# %%
test_set = dataset_test.iloc[:,1:2].values

# %%
test_set.shape
# Out:
# (125, 1)

# %%
dataset_total = pd.concat((dataset_train['Open'],dataset_test['Open']),axis=0)

# %%
inputs = dataset_total.values
inputs = inputs.reshape(-1,1)
inputs_scaled=sc.transform(inputs)
X_test = []
for i in range(60,1384):
  X_test.append(inputs_scaled[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
X_test.shape
# Out:
# (1324, 60, 1)

# %%
predicted_stock_price_scaled = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price_scaled)
# Out:
# 42/42 [==============================] - 0s 4ms/step

# %%
plt.plot(np.arange(0,1384),inputs, color='red', label = 'Test(Real) Google stock price')
plt.plot(np.arange(60,1384),predicted_stock_price, color='blue', label = 'Predicted Google stock price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
